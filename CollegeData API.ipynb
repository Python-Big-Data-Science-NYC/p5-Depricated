# %%
import pandas as pd
import requests

# %%
r=requests.get('https://api.data.gov/ed/collegescorecard/v1/schools?fields=school.name,id,2015.student.demographics.race_ethnicity.white,2015.student.demographics.race_ethnicity.black,2015.student.demographics.race_ethnicity.hispanic,2015.student.demographics.race_ethnicity.asian,2015.student.demographics.race_ethnicity.aian,2015.student.demographics.race_ethnicity.nhpi,2015.student.demographics.race_ethnicity.two_or_more,2015.student.demographics.race_ethnicity.non_resident_alien,2015.student.demographics.race_ethnicity.unknown,2015.student.demographics.race_ethnicity.white_non_hispanic,2015.student.demographics.race_ethnicity.black_non_hispanic,2015.student.demographics.race_ethnicity.asian_pacific_islander&sort=2015.completion.rate_suppressed.overall:desc&api_key=J5SxislQT7YJ1goKSbRtGuDenORTSx3FchOcrIPX')
r.status_code
results_list =r.json()

#results_list['metadata']
#for x in results_list: #['results']:
    #print (results_list[x])


df = pd.DataFrame(results_list['results']) #,  columns=results_list['metadata'])
df.head(5)
df.count()
# Out:
# 2015.student.demographics.race_ethnicity.aian                      20
# 2015.student.demographics.race_ethnicity.asian                     20
# 2015.student.demographics.race_ethnicity.asian_pacific_islander     0
# 2015.student.demographics.race_ethnicity.black                     20
# 2015.student.demographics.race_ethnicity.black_non_hispanic         0
# 2015.student.demographics.race_ethnicity.hispanic                  20
# 2015.student.demographics.race_ethnicity.nhpi                      20
# 2015.student.demographics.race_ethnicity.non_resident_alien        20
# 2015.student.demographics.race_ethnicity.two_or_more               20
# 2015.student.demographics.race_ethnicity.unknown                   20
# 2015.student.demographics.race_ethnicity.white                     20
# 2015.student.demographics.race_ethnicity.white_non_hispanic         0
# id                                                                 20
# school.name                                                        20
# dtype: int64

# %%
r=requests.get('https://api.data.gov/ed/collegescorecard/v1/schools?fields=school.name,id,2013.aid.median_debt.completers.overall,2013.repayment.1_yr_repayment.completers,2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings&page=100&api_key=J5SxislQT7YJ1goKSbRtGuDenORTSx3FchOcrIPX')
r.status_code
results_list =r.json()

#results_list['metadata']
#for x in results_list: #['results']:
    #print (results_list[x])


df = pd.DataFrame(results_list['results']) #,  columns=results_list['metadata'])
#df.head(5)
df.count()
# Out:
# 2013.aid.median_debt.completers.overall                                17
# 2013.earnings.10_yrs_after_entry.working_not_enrolled.mean_earnings    20
# 2013.repayment.1_yr_repayment.completers                               17
# id                                                                     20
# school.name                                                            20
# dtype: int64

# %%
r=requests.get('https://api.data.gov/ed/collegescorecard/v1/schools?id=164924&&api_key=J5SxislQT7YJ1goKSbRtGuDenORTSx3FchOcrIPX')
r.status_code
results_list =r.json()

#results_list['metadata']
#for x in results_list: #['results']:
    #print (results_list[x])


df = pd.DataFrame(results_list['results']) #,  columns=results_list['metadata'])
df.head(5)
#df.count()
# Out:
#                                                 1996  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 1997  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 1998  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 1999  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 2000  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 2001  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 2002  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 2003  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 2004  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 2005  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                          ...                          \
# 0                        ...
#
#                                                 2011  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 2012  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 2013  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 2014  \
# 0  {'completion': {'completion_cohort_less_than_4...
#
#                                                 2015      id  \
# 0  {'completion': {'completion_cohort_less_than_4...  164924
#
#                                 location ope6_id ope8_id  \
# 0  {'lon': -71.171488, 'lat': 42.337688}    2128  212800
#
#                                               school
# 0  {'degrees_awarded': {'predominant': 3, 'highes...
#
# [1 rows x 25 columns]

# %%
r=requests.get('https://api.data.gov/ed/collegescorecard/v1/schools?school.name=boston%20college&api_key=J5SxislQT7YJ1goKSbRtGuDenORTSx3FchOcrIPX')
r.status_code
results_list =r.json()

#results_list['metadata']
#for x in results_list: #['results']:
    #print (results_list[x])


df = pd.DataFrame(results_list['results']) #,  columns=results_list['metadata'])
#df.head(5)
df
# Out:
#                                                 1996  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3                                                NaN
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 1997  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 1998  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 1999  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 2000  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 2001  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 2002  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 2003  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 2004  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 2005  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
# 5                        ...
#
#                                                 2011  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 2012  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 2013  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 2014  \
# 0  {'completion': {'completion_cohort_less_than_4...
# 1  {'completion': {'completion_cohort_less_than_4...
# 2  {'completion': {'completion_cohort_less_than_4...
# 3  {'completion': {'completion_cohort_less_than_4...
# 4  {'completion': {'completion_cohort_less_than_4...
# 5                                                NaN
#
#                                                 2015      id  \
# 0  {'completion': {'completion_cohort_less_than_4...  164924
# 1  {'completion': {'completion_cohort_less_than_4...  205522
# 2  {'completion': {'completion_cohort_less_than_4...  164872
# 3  {'completion': {'completion_cohort_less_than_4...  429128
# 4  {'completion': {'completion_cohort_less_than_4...  164614
# 5  {'completion': {'completion_cohort_less_than_4...  487144
#
#                                 location ope6_id  ope8_id  \
# 0  {'lon': -71.171488, 'lat': 42.337688}    2128   212800
# 1  {'lon': -82.937763, 'lat': 38.751229}   20568  2056803
# 2   {'lon': -71.085851, 'lat': 42.34867}    3966   396600
# 3  {'lon': -71.064378, 'lat': 42.352944}   31305  3130500
# 4    {'lon': -71.1103, 'lat': 42.254037}   32483  3248300
# 5   {'lon': -71.076281, 'lat': 42.35069}   42076  4207601
#
#                                               school
# 0  {'degrees_awarded': {'predominant': 3, 'highes...
# 1  {'degrees_awarded': {'predominant': 2, 'highes...
# 2  {'degrees_awarded': {'predominant': 3, 'highes...
# 3  {'degrees_awarded': {'predominant': 2, 'highes...
# 4  {'degrees_awarded': {'predominant': 3, 'highes...
# 5  {'degrees_awarded': {'predominant': 1, 'highes...
#
# [6 rows x 25 columns]

# %%
df.school[3]['name']
# Out:
# 'Urban College of Boston'

# %%
r=requests.get('https://api.data.gov/ed/collegescorecard/v1/schools?school.name=boston%20college&api_key=J5SxislQT7YJ1goKSbRtGuDenORTSx3FchOcrIPX')
r.status_code
results_list =r.json()

#results_list['metadata']
#for x in results_list: #['results']:
    #print (results_list[x])


df = pd.DataFrame(results_list['results']) #,  columns=results_list['metadata'])
#df.head(5)
df
    
df.count()
# Out:
# 1996        4
# 1997        5
# 1998        5
# 1999        5
# 2000        5
# 2001        5
# 2002        5
# 2003        5
# 2004        5
# 2005        5
# 2006        5
# 2007        5
# 2008        5
# 2009        5
# 2010        5
# 2011        5
# 2012        5
# 2013        5
# 2014        5
# 2015        6
# id          6
# location    6
# ope6_id     6
# ope8_id     6
# school      6
# dtype: int64

# %%
r=requests.get('https://api.data.gov/ed/collegescorecard/v1/schools?fields=school.name&api_key=J5SxislQT7YJ1goKSbRtGuDenORTSx3FchOcrIPX')
r.status_code
results_list =r.json()

#results_list['metadata']
#for x in results_list: #['results']:
    #print (results_list[x])


df = pd.DataFrame(results_list['results']) #,  columns=results_list['metadata'])
#df.head(5)
df
    
df.count()
# Out:
# school.name    20
# dtype: int64
